# %%
import numpy as np
import pandas as pd
from collections import defaultdict
import csv

# %%
def get_data(comm_markets_path, distances_path):
    '''
    A function that pulls in the data from marketcommodities.ini and the flc dump file and scrapes it. 
    +++++++++
    Parameters:
    comm_markets_path (str): the path of market_commodities.ini
    distances_path (str): the path of the flc dump file
    +++++++++
    Returns
    distances (Dataframe): pandas dataframe of all the viable distances between bases
    bases(list of dictonaries): list containing all of the base entries in market_commodities.ini in dictonary 
    form. Dictonaies hold base_code, base_name, and list of commodities traded. 
    comm_set (set): set of all commodities bought or sold on all bases
    base_names (list): all base names
    '''


    distances = pd.read_csv(distances_path, names = ['start', 'end', 'time'])
    distances = distances[distances['start']!=distances['end']]
    distances = distances[distances['time']!=-1]

    with open(comm_markets_path, 'r') as file:
        lines = file.readlines() 
    
    comment_count = 0
    bases = []
    commodities =[]
    for i in lines[2:]:
        if i.lower() == '[basegood]\n' or i == ';EVERYTHING BELOW THIS LINE IS DATABASE.':
            if comment =='':
                comment = base_code
            bases.append({'base_code':base_code.strip('\n'), 'Name':comment.strip('\n'), 'commodities':commodities})
            commodities=[]
            comment = ''
            comment_count = 0
        if i[:4].lower() == "base":
            base_code = i[7:]
            
        if i[:1] == ';' and comment_count == 0:
            comment = i[1:]
            comment_count+=1
        elif i[:1]==';':
            print(i)
            comment +'\n'+ i
        if i[:10].lower() == 'marketgood':
            t =i[13:].split()
            l = [float(j.strip(',')) for j in t[1:6]]
            l.append(float(t.pop()))
            l.append(t[0])
            commodities.append(l)
    
    comm_set = set([])
    for i in bases: #this loop in loop adds all the commodities to a set so we know how many commodities to display in our applet
        j = i['commodities']
        for k in j:
            comm_set.add(k[6])
    base_names=[(base['Name'],base['base_code']) for base in bases]
    
    return distances, bases, comm_set, base_names,

# %%
def which_sell(commodity_list):
    '''
    A helperfunction that digs through the bases list generated by get_data and finds which ones sell any of a given list of commodities
    
    Paramaters
    commodity_list(list): a list of the commodity codes (strings) you want to find where they're sold
    
    Returns
    list of bases (list): list of base codes that sell any of the given commodities
    '''
    sells_set = set([])
    for i in bases:
        for k in i['commodities']:
            if k[-1] in commodity_list and k[-3]== 0:
                sells_set.add(i['base_code'])
    l = list(sells_set)
    return [i.strip('\n') for i in l]

# %%
def sort_by_closest_base(list_of_bases, distances):
    '''
    a function that takes the distances dataframe and any list of bases and sorts all the other bases out into the lists of bases closest to those bases in the list of bases. 
    Its got a lot of fuckery, and maybe can be given another pass for better algorithmic complexity. I'm so sorry. 
    
    Parameters 
    list_of_bases (list): a list of string base codes
    distances (DataFrame): the base to base travel times from flcomp formatted as a DataFrame by get_data()
    
    Returns:
    sorted_l (list of lists) list of list of bases, sorted in the same shape as the list of bases fed in, 
    with each list containing those bases that are closest to the base listed at the same index in list_of_bases
    '''
    k = [distances[distances['start'] == i] for i in list_of_bases] # makes a list of dataframes of routes starting from the bases in question
    k = [i[~i['end'].isin(list_of_bases)].reset_index() for i in k] # gets rid of routes between bases in the  list (because you don't want one producer to sell to the other)
    
    df = pd.DataFrame()
    for idx, i in enumerate(list_of_bases): #peices the list k back together into a larger thing
        df[i]=k[idx]['time']
    df['base'] = k[0]['end']
    df = df.set_index('base')
    #print(df)
    df['time'] = df.min(axis = 1)
    df['shortest'] = df.idxmin(axis = 1)
    df.reset_index(inplace = True)
    df['output'] = list(zip(df['time'], df['base']))

    sorted_bases = df[['base','time','shortest','output']]
    
    #sorted_bases = sorted_bases.reset_index()
    sorted_l =[]

    for i in list_of_bases:
        sorted_l.append(sorted_bases[sorted_bases['shortest']==i]['output'].to_list())

    return sorted_l

# %%
def commodities_from_config(config):
    '''
    takes the config (whatever that turns out to be like, right now its a list of lists) and spits out all of the commodites used
    '''
    
    comm_set = set()
    for locations in config:
        comm_set.update(locations[1])
        comm_set.update(locations[2])
        comm_set.update(locations[3])
    return comm_set

# %%
def lookup(bases):
    '''
    A helperfunction to produce a pair of dictonaries that associate base codes to base names and back again. 
    
    '''
    keys = [base['Name'].strip('\n') for base in bases]
    values = [base['base_code'].strip('\n').lower() for base in bases]
    base_code_lookup = {keys[i]: values[i] for i in range(len(keys))} 
    base_name_lookup = {values[i]:keys[i] for i in range(len(keys))}
    return base_code_lookup, base_name_lookup

# %%
def find_nearest_x(base_code, num, distances):
    '''
    given the list of distances, finds the nearest num bases to base given
    '''
    output = distances[distances['start'] == base_code].sort_values('time', axis = 0).head(num)['end'].to_list()
    return output

# %%
def gen_market_from_config(config, distances):
    '''
    function that reads the config file(currently a list of lists) and turns that into a dictonary much closer to the marketgoods ini for the backwards-parser to turn into a text file. 
    A COUPLE BASES AREN'T GETTING THEIR FRICKING PURCHASES RECORDED STILL. SORT THAT OUT. 
    
    Parameters
    ++++++++
    config (list of lists): bases that buy and sell each commodity, formatted into a list containing [base name, commodity base produces, comody base resells, comodity base consumes]
    distances(df): dataframe of all base to base travel times
    ++++++++
    Returns
    market_goods(defaultdict(list)):
    '''
    
    comms = commodities_from_config(config)
    
    
    #loop that rolls through the config file and sorts out the bases that consume and produce each thing. 
    market = []
    for commodity in comms:
        bases_that_consume = []
        bases_that_produce = []
            
        for base in config:
            if commodity in base[1]:
                bases_that_produce.append(base[0])
            if commodity in base[3]:
                bases_that_consume.append(base[0])
        
        market.append({'commodity': commodity, 'produces':bases_that_produce,'consumes':bases_that_consume})
    
    
    #loop that takes the market produced above and turns it into a dictonary of bases, commodities, buy-sells, and travel ties. 
    market_goods = defaultdict(list)
    for commodity in market:
    #print(market_goods)
        specific_distances = distances[distances['start'].isin(commodity['produces'])]
        
   
        for location in commodity['produces']:
            market_goods[location].append((commodity['commodity'], 'sells', 1 )) #sets distance for sellers to 1 for purposes of multiplying price by 1. 
        
        sorts = sort_by_closest_base(commodity['produces'], specific_distances)
        #print(sorts)
        consumer = commodity['consumes']
        
        filter_sorts = [[base for base in group if base[1] in consumer] for group in sorts] #nasty comprehension in a comprehension filters out all the bases that are not set as consumers of the commodity
        
        for group in filter_sorts:
            for location in group:
                market_goods[location[1]].append((commodity['commodity'], 'buy', location[0]))
                
                
    return market_goods

# %%
def write_ini(file_path, market, config):
    '''
    function that takes the market dictonary and formats it for freelancer, and saves it as a text file
    ++++++++++
    Parameters
    file_path (str): name and path of file
    market (defaultdict(list)): per base formatting of all commodities
    ++++++++++
    Returns:
    none, 
    writes a file
    '''
    lines = []
    for item in market.keys():

        lines.append('[BaseGood]')
        lines.append('base = '+ item)
        lines.append(';'+base_name_lookup[item])

        for commodity in market[item]:
            if commodity[1] == 'sells':
                function_tag = '1'
            else:
                function_tag = '0'
            price_mult = str(commodity[2]) # For a working version, this needs to reference something in config to set prices
            mgood =['Marketgood =',commodity[0],'0, -1, 0, 0,', function_tag, str(commodity[2])]
            lines.append(' '.join(mgood))

    with open(file_path, 'w') as f:
        for line in lines:
            f.write(line+'\n')

# %%
#load and clean the 
def load_xoria_base_info(path):
    '''
    Helperfunction to load and clean the xoria base entity. The spreadsheet uses a * as a Yes and a blank as a no, those are switched to true false
    ++++++++++
    Parameters
    file_path (str): name and path of file
    ++++++++++
    Returns:
    xbases (Dataframe): pandas dataframe of the spreadsheet. 
    '''
    xbases = pd.read_csv(path)
    xbases[['O2','H2O']] = xbases[['O2', 'H2O']].fillna(-1)
    xbases[['Trade','POB','Deleted','_Location changed', '_Purpose Changed']] = xbases[['Trade','POB','Deleted','_Location changed', '_Purpose Changed']].fillna(False)
    xbases[['Trade','POB','Deleted','_Location changed', '_Purpose Changed']] = xbases[['Trade','POB','Deleted','_Location changed', '_Purpose Changed']].replace('*', True)
    return xbases

# %%
def add_xoria(bases, xoria_bases):
    '''
    function which iterates through Bases and adds the extra information from xoria_bases to each dictonary in bases list. 
    
    
    Returns:
    everydic_not_in_xbases (list): list of every base name in bases that does not have a corresponding base name in Xoria's bases. (these bases are not used in the economy)
    '''
    xbases_not_in_everydic = []
    everydic_not_in_xbases = []
    for everydic in bases:
        
        base_name = everydic['base_code']
        #print(base_name)
        
        xentry = (xoria_bases[xoria_bases["_nickname"]== base_name.lower()].values.flatten().tolist())
        #print(xentry)
        if len(xentry) > 1:
            everydic['Oxygen'] = xentry[0]
            everydic['Water'] = xentry[1]
            everydic['Trade'] = xentry[2]
            everydic['POB'] = xentry[3]
            everydic['Deleted'] = xentry[4]
            everydic['Faction']=xentry[8]
            everydic['System']=xentry[9]
            everydic['Region']=xentry[10]
            everydic['Purpose']=xentry[11]
            everydic['Location Changed']=xentry[12]
            everydic['Purpose Changed']=xentry[13]
        else:
            everydic_not_in_xbases.append(base_name)
            
    return everydic_not_in_xbases

# %%
path_markets = 'market_commodities.ini'
distances_path = 'dump.csv'

distances, bases, comm_set, base_names = get_data(path_markets, distances_path)
base_code_lookup, base_name_lookup = lookup(bases)

xpath = 'Discovery_Economy/Bases.csv'
xoria_bases = load_xoria_base_info(xpath)
missing = add_xoria(bases, xoria_bases)

# %%
xbases[xbases['_nickname'] == 'ga03_09_base']['O2'][0]
# Out:
# 3.0

# %%
for base in bases[:2]:
    code = base['base_code'].strip('\n').lower()
    xb_entry = xoria_bases[xoria_bases['_nickname'] == code]
    print(xb_entry["_Faction"].values[0])
# Out:
# BPA
# BMM

# %%
def where_sold(bases, comm_set):
    '''
    a function which iterates across comm_set and finds the lowest sell point(base) of every commodity
    +++++
    Parameters
    bases(list of dictonaries): list containing all of the base entries in market_commodities.ini in dictonary 
        form. Dictonaies hold base_code, base_name, and list of commodities traded. 
    comm_set (set): set of all commodities bought or sold on all bases
    ++++++
    Returns
    production_points (list): list of tuples of the bases that sell each base for the lowest price
    comm_set_but_not_in_will_sell: (list) commodities that are not sold on any base, only bought
    '''
    #find the commodity produced by any base in bases (lowest price and sold)

    will_sell = [] #below [[base, commodity, multiplier]]
    for everydic in bases:
        for everycom in everydic['commodities']:
            if everycom[4] == 0: 
                will_sell.append([everydic['base_code'],everycom[6],everycom[5]])
    will_sell = np.array(will_sell)
    #from will_sell, find the minimum sale point of each commodity in comm_set

    production_points =[]
    comm_set_but_not_in_bases =[]
    for commodity in comm_set:

        popout = will_sell[will_sell[:,1] == commodity]

        multipliers = popout[:,2]
        if len(multipliers) < 1:
            comm_set_but_not_in_bases.append(commodity)
        else:
            low = min(multipliers)
            producers = popout[popout[:,2] == low]

            production_points.append((commodity, low, list(producers[:,0])))
            
    return comm_set_but_not_in_bases, production_points

# %%
n, production_points = where_sold(bases, comm_set)

# %%
popout = will_sell[will_sell[:,1] == commodity]
multipliers = popout[:,2]
low = min(multipliers)
producers = popout[popout[:,2] == low]
something.append(commodity, low, list(producers[:,0]))

# %%
production_points
# Out:
# [('commodity_liquid_cardamine,', '1.4', ['ST05_01_Base']),
#  ('commodity_energy_field_equip,', '1.245', ['GA03_09_Base']),
#  ('commodity_violation9,', '1.0', ['IW09_03_Base']),
#  ('commodity_violation8,', '1.0', ['IW09_03_Base']),
#  ('commodity_bluediamonds,', '1.0', ['GA04_01_Base']),
#  ('commodity_plastics,', '1.195', ['GA02_05_Base']),
#  ('commodity_credit1,',
#   '1.0',
#   ['Br01_01_base',
#    'Br01_02_base',
#    'Br01_03_base',
#    'Br01_04_base',
#    'Br01_05_base',
#    'Br01_06_base',
#    'Br01_07_base',
#    'Br01_08_base',
#    'Br01_hgn01_base',
#    'Br02_01_base',
#    'Br02_02_base',
#    'Br02_03_base',
#    'Br02_04_base',
#    'Br02_05_base',
#    'Br03_01_base',
#    'Br03_02_base',
#    'Br03_03_base',
#    'Br03_04_base',
#    'Br03_05_Base',
#    'Br03_06_base',
#    'Br04_01_base',
#    'Br04_02_base',
#    'Br04_03_base',
#    'Br04_04_base',
#    'Br04_05_base',
#    'Br04_06_base',
#    'Br05_01_base',
#    'Br05_03_base',
#    'Br05_04_base',
#    'Br05_05_base',
#    'Br06_03_base',
#    'Br06_04_base',
#    'Bw01_01_base',
#    'Bw01_02_base',
#    'Bw01_03_base',
#    'Bw01_04_base',
#    'Bw02_01_base',
#    'Bw02_02_base',
#    'Bw03_01_base',
#    'Bw03_02_base',
#    'Bw03_03_base',
#    'Bw04_01_base',
#    'Bw04_02_base',
#    'Bw05_01_base',
#    'Bw05_02_base',
#    'Bw05_03_base',
#    'Bw06_01_base',
#    'Bw06_02_base',
#    'Bw07_01_base',
#    'Bw07_02_base',
#    'Bw08_01_base',
#    'Bw08_02_base',
#    'Bw08_03_base',
#    'Bw09_01_base',
#    'Bw09_02_base',
#    'Bw09_03_base',
#    'Bw10_01_base',
#    'Bw10_02_base',
#    'Bw10_03_base',
#    'Bw10_04_base',
#    'Ew01_01_base',
#    'Ew01_02_base',
#    'Ew02_01_base',
#    'Ew02_02_base',
#    'Ew03_01_base',
#    'Ew03_02_base',
#    'Ew04_01_base',
#    'Ew04_02_base',
#    'EW12_01_base',
#    'Hi01_01_base',
#    'Hi01_02_base',
#    'Hi02_01_base',
#    'Hi02_02_base',
#    'Iw01_01_base',
#    'Iw01_02_base',
#    'Iw02_01_base',
#    'Iw02_02_base',
#    'Iw03_01_base',
#    'Iw03_02_base',
#    'Iw04_01_base',
#    'Iw04_02_base',
#    'Iw05_01_base',
#    'Iw05_02_base',
#    'Iw06_01_base',
#    'Iw06_02_base',
#    'Ku01_01_base',
#    'Ku01_02_base',
#    'Ku01_03_base',
#    'Ku01_04_base',
#    'Ku01_05_base',
#    'Ku01_06_base',
#    'Ku01_07_base',
#    'Ku02_01_base',
#    'Ku02_02_base',
#    'Ku02_03_base',
#    'Ku02_04_base',
#    'Ku02_05_base',
#    'Ku03_01_base',
#    'Ku03_02_base',
#    'Ku03_03_base',
#    'Ku03_04_base',
#    'Ku03_05_base',
#    'Ku04_01_base',
#    'Ku04_02_base',
#    'Ku04_03_base',
#    'Ku04_04_base',
#    'Ku04_05_base',
#    'Ku04_06_base',
#    'ew37_01_base',
#    'EW37_02_Base',
#    'Ku05_01_base',
#    'Ku05_02_base',
#    'Ku05_03_base',
#    'Ku05_04_base',
#    'Ku06_01_base',
#    'Li01_01_base',
#    'Li01_02_base',
#    'Li01_03_base',
#    'Li01_06_base',
#    'Li01_07_base',
#    'Li01_08_base',
#    'Li01_09_base',
#    'Li01_10_base',
#    'Li01_11_base',
#    'Li01_12_base',
#    'Li01_13_base',
#    'Li01_14_base',
#    'Li01_hgn01_base',
#    'Li02_01_base',
#    'Li02_02_base',
#    'Li02_03_base',
#    'Li02_04_base',
#    'Li02_05_base',
#    'Li02_06_base',
#    'Li03_01_base',
#    'Li03_02_base',
#    'Li03_03_base',
#    'Li03_04_base',
#    'Li04_01_base',
#    'Li04_02_base',
#    'Li04_03_base',
#    'Li04_04_base',
#    'Li04_05_base',
#    'Li05_01_base',
#    'Li05_02_base',
#    'Rh01_01_base',
#    'Rh01_02_base',
#    'Rh01_03_base',
#    'Rh01_04_base',
#    'Rh01_05_base',
#    'Rh01_06_base',
#    'Rh01_07_base',
#    'Rh01_08_base',
#    'Rh02_01_base',
#    'Rh02_02_base',
#    'Rh02_03_base',
#    'Rh02_04_base',
#    'Rh02_05_base',
#    'Rh02_06_base',
#    'Rh03_01_base',
#    'Rh03_02_base',
#    'Rh03_03_base',
#    'Rh03_04_base',
#    'Rh03_05_base',
#    'Rh03_06_base',
#    'Rh04_01_base',
#    'Rh04_02_base',
#    'Rh04_03_base',
#    'Rh04_04_base',
#    'Rh04_05_base',
#    'Rh05_01_base',
#    'Rh05_02_base',
#    'Rh05_03_base',
#    'Rh05_04_base',
#    'br_m_hydrocarbon_miner',
#    'br_m_niobium_miner',
#    'co_ti_water_miner',
#    'co_shi_h-fuel_miner',
#    'co_khc_copper_miner',
#    'co_khc_cobalt_miner',
#    'rh_m_diamond_miner',
#    'gd_im_silver_miner',
#    'gd_im_copper_miner',
#    'gd_gm_H-fuel_miner',
#    'gd_im_water_miner',
#    'gd_im_oxygen_miner',
#    'co_shi_water_miner',
#    'co_kt_hydrocarbon_miner',
#    'br_m_beryllium_miner',
#    'Ew06_01_base',
#    'Ew06_02_base',
#    'Ew06_03_base',
#    'Ew06_04_base',
#    'Ew06_05_base',
#    'ST04_01_base',
#    'ST04_02_base',
#    'BR07_01_Base',
#    'BR07_02_Base',
#    'BR07_03_Base',
#    'BR07_04_Base',
#    'BR07_05_Base',
#    'BR07_06_Base',
#    'BR07_07_Base',
#    'BR07_08_Base',
#    'BR07_09_Base',
#    'BR07_10_Base',
#    'BR07_11_Base',
#    'BW11_01_Base',
#    'BW11_02_Base',
#    'BW11_03_Base',
#    'EW07_01_Base',
#    'EW07_02_Base',
#    'EW08_01_Base',
#    'EW08_02_Base',
#    'RH06_01_Base',
#    'RH06_02_Base',
#    'RH06_03_Base',
#    'RH06_05_Base',
#    'RH06_06_Base',
#    'Li02_07_Base',
#    'Rh01_09_Base',
#    'Rh03_07_Base',
#    'Rh04_06_Base',
#    'Rh04_07_Base',
#    'Rh05_05_Base',
#    'BR16_01_Base',
#    'BR16_02_Base',
#    'BR16_03_Base',
#    'BR19_01_Base',
#    'BR22_01_Base',
#    'BR22_02_Base',
#    'BR22_03_Base',
#    'BR22_04_Base',
#    'BW13_01_Base',
#    'BW16_01_Base',
#    'BW16_02_Base',
#    'BW16_03_Base',
#    'BW16_04_Base',
#    'BW21_01_Base',
#    'BW21_02_Base',
#    'BW21_03_Base',
#    'BW71_01_Base',
#    'BW71_02_Base',
#    'BW71_03_Base',
#    'BW46_01_Base',
#    'BW46_02_Base',
#    'BW69_01_Base',
#    'BW69_02_Base',
#    'BW69_03_Base',
#    'BW01_05_Base',
#    'BW69_04_Base',
#    'EW45_01_Base',
#    'EW85_01_Base',
#    'EW85_02_Base',
#    'EW85_04_Base',
#    'EW85_06_Base',
#    'HI08_01_Base',
#    'HI10_01_Base',
#    'HI10_02_Base',
#    'HI10_03_Base',
#    'HI18_01_Base',
#    'HI18_02_Base',
#    'HI18_03_Base',
#    'HI18_04_Base',
#    'IW07_01_Base',
#    'IW08_01_Base',
#    'IW08_02_Base',
#    'IW08_03_Base',
#    'IW08_04_Base',
#    'IW12_01_Base',
#    'IW13_01_Base',
#    'KU09_01_Base',
#    'KU15_01_Base',
#    'KU16_01_Base',
#    'KU17_01_Base',
#    'KU17_02_Base',
#    'LI10_01_Base',
#    'LI15_01_Base',
#    'LI15_02_Base',
#    'LI15_03_Base',
#    'LI15_04_Base',
#    'LI18_01_Base',
#    'LI18_02_Base',
#    'LI18_03_Base',
#    'LI18_04_Base',
#    'RH09_01_Base',
#    'RH10_01_Base',
#    'RH11_01_Base',
#    'RH11_02_Base',
#    'RH11_03_Base',
#    'RH12_01_Base',
#    'KU16_02_Base',
#    'KU16_03_Base',
#    'BR19_02_Base',
#    'RH10_02_Base',
#    'Br04_07_base',
#    'BW58_01_Base',
#    'BW12_01_Base',
#    'BW12_02_Base',
#    'BW12_03_Base',
#    'BW12_04_Base',
#    'BW12_05_Base',
#    'EW09_01_Base',
#    'EW09_02_Base',
#    'EW09_03_Base',
#    'EW09_04_Base',
#    'ST05_01_Base',
#    'ST06_01_Base',
#    'IW09_01_Base',
#    'IW09_02_Base',
#    'Hi01_03_base',
#    'HI05_01_Base',
#    'BR09_01_Base',
#    'BR09_02_Base',
#    'BR09_03_Base',
#    'BR13_01_Base',
#    'EW12_02_Base',
#    'EW12_03_Base',
#    'EW12_04_Base',
#    'EW63_01_Base',
#    'EW63_02_Base',
#    'EW63_03_Base',
#    'KU09_02_Base',
#    'KU09_03_Base',
#    'KU10_01_Base',
#    'LI08_01_Base',
#    'LI08_02_Base',
#    'LI08_03_Base',
#    'LI08_04_Base',
#    'LI12_01_Base',
#    'LI12_02_Base',
#    'LI12_03_Base',
#    'LI12_04_Base',
#    'LI12_05_Base',
#    'LI12_06_Base',
#    'LI12_07_Base',
#    'LI10_02_Base',
#    'LI13_01_Base',
#    'LI13_02_Base',
#    'LI11_01_Base',
#    'LI14_01_Base',
#    'LI14_02_Base',
#    'LI09_01_Base',
#    'LI09_02_Base',
#    'LI09_03_Base',
#    'LI09_04_Base',
#    'LI09_05_Base',
#    'LI09_06_Base',
#    'LI09_07_Base',
#    'RH08_01_Base',
#    'RH08_02_Base',
#    'RH12_02_Base',
#    'Iw02_04_Base',
#    'Li05_03_Base',
#    'Br02_06_Base',
#    'EW07_03_Base',
#    'Rh02_08_Base',
#    'RH06_04_Base',
#    'RH06_07_Base',
#    'HI20_01_Base',
#    'HI20_02_Base',
#    'HI20_03_Base',
#    'HI20_04_Base',
#    'RH08_03_Base',
#    'ST04_04_Base',
#    'KU08_01_Base',
#    'KU08_02_Base',
#    'KU08_03_Base',
#    'Rh01_10_Base',
#    'LI13_03_Base',
#    'LI13_04_Base',
#    'LI13_05_Base',
#    'IW13_02_Base',
#    'IW13_03_Base',
#    'IW13_04_Base',
#    'IW13_05_Base',
#    'IW13_08_Base',
#    'Li05_04_Base',
#    'Li05_05_Base',
#    'EW45_02_Base',
#    'EW45_03_Base',
#    'EW45_04_Base',
#    'BW13_02_Base',
#    'BW13_03_Base',
#    'BW46_03_Base',
#    'BW46_04_Base',
#    'IW12_02_Base',
#    'IW12_03_Base',
#    'LI16_01_Base',
#    'LI16_02_Base',
#    'LI16_03_Base',
#    'Bw01_06_Base',
#    'HI03_01_Base',
#    'HI03_02_Base',
#    'HI03_03_Base',
#    'HI03_04_Base',
#    'Hi02_03_Base',
#    'Ku07_01_Base',
#    'LI09_08_Base',
#    'Br04_08_Base',
#    'KU13_01_Base',
#    'KU13_02_Base',
#    'KU13_03_Base',
#    'KU13_04_Base',
#    'KU13_05_Base',
#    'KU13_06_Base',
#    'KU13_10_Base',
#    'ST05_02_Base',
#    'IW11_01_Base',
#    'IW13_06_Base',
#    'IW13_07_Base',
#    'IW11_02_Base',
#    'IW11_03_Base',
#    'IW11_04_Base',
#    'IW11_05_Base',
#    'LI07_01_Base',
#    'IW07_02_Base',
#    'BR14_01_Base',
#    'IW09_03_Base',
#    'No01_01_Base',
#    'RH06_08_Base',
#    'BW14_01_Base',
#    'BW14_02_Base',
#    'BW14_03_Base',
#    'EW07_04_Base',
#    'LI10_03_Base',
#    'LI10_04_Base',
#    'LI10_05_Base',
#    'BR17_01_Base',
#    'BR17_02_Base',
#    'BR17_03_Base',
#    'BW15_01_Base',
#    'BW15_02_Base',
#    'BW15_03_Base',
#    'BW15_04_Base',
#    'BW15_05_Base',
#    'BW15_06_Base',
#    'BW17_01_Base',
#    'BW17_02_Base',
#    'RH07_01_Base',
#    'RH07_02_Base',
#    'RH07_03_Base',
#    'RH07_04_Base',
#    'RH07_05_Base',
#    'ST07_01_Base',
#    'ST08_02_Base',
#    'ST08_03_Base',
#    'ST39_02_Base',
#    'ST39_04_Base',
#    'EW18_01_Base',
#    'EW18_02_Base',
#    'EW19_01_Base',
#    'EW19_02_Base',
#    'EW19_03_Base',
#    'EW19_04_Base',
#    'BR08_02_Base',
#    'BR08_03_Base',
#    'Br06_01_base',
#    'Br06_02_base',
#    'BR08_01_Base',
#    'BR08_04_Base',
#    'BR08_05_Base',
#    'BR10_01_Base',
#    'BR10_02_Base',
#    'Bw08_04_Base',
#    'Bw10_05_Base',
#    'EW13_01_Base',
#    'EW13_02_Base',
#    'EW13_03_Base',
#    'EW13_04_Base',
#    'EW13_05_Base',
#    'EW13_06_Base',
#    'EW13_07_Base',
#    'EW14_01_Base',
#    'EW14_02_Base',
#    'EW14_03_Base',
#    'EW14_04_Base',
#    'EW14_05_Base',
#    'EW14_06_Base',
#    'EW14_07_Base',
#    'EW15_01_Base',
#    'EW15_02_Base',
#    'EW15_03_Base',
#    'EW15_04_Base',
#    'EW15_05_Base',
#    'EW15_06_Base',
#    'EW15_07_Base',
#    'EW15_08_Base',
#    'EW15_09_Base',
#    'EW15_10_Base',
#    'EW15_11_Base',
#    'EW16_01_Base',
#    'EW16_02_Base',
#    'EW16_03_Base',
#    'EW16_04_Base',
#    'EW16_05_Base',
#    'EW16_06_Base',
#    'EW16_07_Base',
#    'EW16_08_Base',
#    'EW16_09_Base',
#    'EW16_10_Base',
#    'EW17_01_Base',
#    'EW17_02_Base',
#    'EW17_03_Base',
#    'EW17_04_Base',
#    'EW17_05_Base',
#    'EW17_06_Base',
#    'EW17_07_Base',
#    'EW17_08_Base',
#    'GA01_01_Base',
#    'GA01_02_Base',
#    'GA01_03_Base',
#    'GA01_04_Base',
#    'GA01_05_Base',
#    'GA01_06_Base',
#    'GA01_08_Base',
#    'GA01_09_Base',
#    'GA01_10_Base',
#    'GA01_12_Base',
#    'GA01_13_Base',
#    'GA01_14_Base',
#    'GA01_15_Base',
#    'GA01_16_Base',
#    'GA01_18_Base',
#    'GA01_19_Base',
#    'GA02_01_Base',
#    'GA02_02_Base',
#    'GA02_03_Base',
#    'GA02_04_Base',
#    'GA02_05_Base',
#    'GA02_06_Base',
#    'GA02_07_Base',
#    'GA02_09_Base',
#    'GA02_10_Base',
#    'GA02_11_Base',
#    'GA02_12_Base',
#    'GA03_01_Base',
#    'GA03_02_Base',
#    'GA03_03_Base',
#    'GA03_05_Base',
#    'GA03_06_Base',
#    'GA03_07_Base',
#    'GA03_08_Base',
#    'GA03_09_Base',
#    'GA03_10_Base',
#    'GA03_11_Base',
#    'GA04_01_Base',
#    'GA04_02_Base',
#    'GA04_03_Base',
#    'GA04_04_Base',
#    'GA04_05_Base',
#    'GA04_06_Base',
#    'GA04_07_Base',
#    'GA04_08_Base',
#    'GA04_09_Base',
#    'GA04_10_Base',
#    'GA05_01_Base',
#    'GA05_02_Base',
#    'GA05_03_Base',
#    'GA05_04_Base',
#    'GA05_05_Base',
#    'GA05_06_Base',
#    'GA05_07_Base',
#    'GA05_08_Base',
#    'GA05_09_Base',
#    'GA05_10_Base',
#    'GA05_11_Base',
#    'GA06_01_Base',
#    'GA06_02_Base',
#    'GA06_03_Base',
#    'GA06_04_Base',
#    'GA06_05_Base',
#    'GA06_06_Base',
#    'GA06_07_Base',
#    'GA06_08_Base',
#    'GA06_09_Base',
#    'GA06_10_Base',
#    'GA07_01_Base',
#    'GA07_02_Base',
#    'GA07_03_Base',
#    'GA07_04_Base',
#    'GA07_05_Base',
#    'GA07_06_Base',
#    'GA07_07_Base',
#    'GA07_08_Base',
#    'GA08_01_Base',
#    'GA08_02_Base',
#    'GA08_03_Base',
#    'GA08_04_Base',
#    'GA08_05_Base',
#    'GA08_06_Base',
#    'GA08_07_Base',
#    'GA08_08_Base',
#    'GA08_09_Base',
#    'GA09_01_Base',
#    'GA09_02_Base',
#    'GA10_01_Base',
#    'GA11_01_Base',
#    'GA11_02_Base',
#    'GA12_01_Base',
#    'GA13_01_Base',
#    'GA14_01_Base']),
#  ('commodity_ex_entertainers,', '1.0', ['EW63_01_Base']),
#  ('commodity_travelers,', '1.0', ['Li03_01_base']),
#  ('commodity_consumer_goods_br,', '16.68', ['Br02_01_base']),
#  ('commodity_shapememoryalloy,', '1.295', ['EW15_02_Base']),
#  ('commodity_introduction,',
#   '1.0',
#   ['Br01_01_base',
#    'Ku01_01_base',
#    'Li01_01_base',
#    'Rh01_01_base',
#    'IW09_03_Base']),
#  ('commodity_plasfoam,',
#   '1.0',
#   ['Bw01_03_base',
#    'Bw01_04_base',
#    'Ew03_02_base',
#    'Ku03_02_base',
#    'Ku03_05_base']),
#  ('commodity_premiumscrap,', '1.0', ['IW09_03_Base']),
#  ('commodity_ship_hull_panels_st,', '1.596', ['BR07_10_Base']),
#  ('commodity_gacommander,', '1.0', ['IW09_03_Base']),
#  ('commodity_recon_module,',
#   '1.0',
#   ['Br03_01_base',
#    'Bw06_02_base',
#    'Bw09_03_base',
#    'Ew03_02_base',
#    'Iw05_01_base',
#    'Ku03_04_base',
#    'Ku04_04_base',
#    'Li02_04_base',
#    'ST04_02_base',
#    'BR07_02_Base',
#    'Rh04_07_Base',
#    'BW71_03_Base',
#    'LI15_03_Base',
#    'BW12_03_Base',
#    'EW09_02_Base',
#    'EW63_01_Base',
#    'LI08_03_Base',
#    'RH08_03_Base',
#    'LI16_01_Base',
#    'HI03_03_Base',
#    'Ku07_02_Base',
#    'KU13_05_Base',
#    'IW11_01_Base',
#    'IW13_06_Base',
#    'IW13_07_Base',
#    'RH07_02_Base',
#    'ST08_03_Base',
#    'EW18_01_Base',
#    'GA01_18_Base',
#    'GA03_11_Base',
#    'GA08_07_Base']),
#  ('commodity_hazmat_canisters,', '3.99', ['Rh01_05_base']),
#  ('commodity_H_fuel,', '1.29', ['KU13_04_Base']),
#  ('commodity_research_corps,',
#   '1.0',
#   ['Br03_02_base',
#    'Bw06_02_base',
#    'Bw09_03_base',
#    'Ew03_02_base',
#    'Iw05_01_base',
#    'Ku03_04_base',
#    'Ku04_04_base',
#    'Li02_04_base',
#    'ST04_02_base',
#    'BR07_02_Base',
#    'Rh04_07_Base',
#    'BW71_03_Base',
#    'LI15_03_Base',
#    'BW12_03_Base',
#    'EW09_02_Base',
#    'EW63_01_Base',
#    'LI08_03_Base',
#    'RH08_03_Base',
#    'LI16_01_Base',
#    'HI03_03_Base',
#    'Ku07_02_Base',
#    'KU13_05_Base',
#    'IW11_01_Base',
#    'IW13_06_Base',
#    'IW13_07_Base',
#    'RH07_02_Base',
#    'ST08_03_Base',
#    'EW18_01_Base',
#    'GA01_18_Base',
#    'GA03_11_Base',
#    'GA08_07_Base']),
#  ('commodity_wine,', '1.0', ['GA01_02_Base']),
#  ('commodity_gatecell,',
#   '1.0',
#   ['ST04_03_base',
#    'BW12_01_Base',
#    'BW12_02_Base',
#    'BW12_03_Base',
#    'ST05_01_Base',
#    'ST06_01_Base',
#    'LI10_02_Base',
#    'Ku07_02_Base',
#    'ST05_02_Base',
#    'BR14_01_Base',
#    'BW17_01_Base',
#    'BW17_02_Base']),
#  ('commodity_xenobiotic,', '1.036', ['Iw02_04_Base']),
#  ('commodity_rice,', '1.29', ['Ku03_01_base']),
#  ('commodity_ultralloy,', '1.445', ['GA04_03_Base']),
#  ('commodity_prisoners,', '1.0', ['EW08_01_Base', 'EW18_02_Base']),
#  ('commodity_platinum,',
#   '1.0',
#   ['LI12_01_Base', 'LI12_05_Base', 'LI12_06_Base']),
#  ('commodity_zinc,', '1.79', ['GA04_01_Base']),
#  ('commodity_unionecorse,', '1.0', ['IW09_03_Base']),
#  ('commodity_serverrules,',
#   '1.0',
#   ['Br01_01_base',
#    'Hi01_01_base',
#    'Hi02_01_base',
#    'Ku01_01_base',
#    'Li01_01_base',
#    'Rh01_01_base',
#    'ST05_01_Base',
#    'IW09_01_Base',
#    'IW09_02_Base',
#    'IW09_03_Base']),
#  ('commodity_iridium,', '1.198', ['ST04_02_base', 'LI10_01_Base']),
#  ('commodity_optical_chips,', '1.145', ['Ku01_05_base']),
#  ('commodity_kuadmiral,', '1.0', ['IW09_03_Base']),
#  ('commodity_violation5,', '1.0', ['IW09_03_Base']),
#  ('commodity_violation6,', '1.0', ['IW09_03_Base']),
#  ('commodity_lsf,', '1.0', ['IW09_03_Base']),
#  ('commodity_optronics,', '1.192', ['Ku04_01_base']),
#  ('commodity_food_ga,', '1.9', ['GA02_01_Base']),
#  ('commodity_boron,', '1.59', ['Li01_02_base', 'GA06_05_Base']),
#  ('commodity_whisky,', '1.495', ['Br05_05_base']),
#  ('commodity_hydrocarbons,', '1.29', ['BR07_07_Base']),
#  ('commodity_cobalt,', '1.69', ['Bw03_02_base']),
#  ('commodity_deuterium,', '1.0', ['EW08_01_Base']),
#  ('commodity_ship_hull_panels,', '1.596', ['Rh01_05_base']),
#  ('commodity_dtfuel,', '1.676', ['Rh04_03_base']),
#  ('commodity_passengers_bw,', '1.0', ['Bw07_01_base', 'GA08_01_Base']),
#  ('commodity_rhcaptain,', '1.0', ['IW09_03_Base']),
#  ('commodity_kemwer,', '1.5', ['ST08_03_Base']),
#  ('commodity_stabiline,', '1.995', ['Bw06_02_base']),
#  ('commodity_magnets,', '1.145', ['GA04_07_Base']),
#  ('commodity_lpg,', '1.195', ['GA03_07_Base', 'GA03_08_Base']),
#  ('commodity_sunbucks,', '1.0', ['Li01_11_base']),
#  ('commodity_superconductors,', '10.88', ['LI13_03_Base']),
#  ('commodity_holmium,', '1.99', ['EW13_01_Base']),
#  ('commodity_scrap_metal,', '1.0', ['EW85_02_Base']),
#  ('commodity_excursionists,', '1.0', ['Ku04_01_base', 'GA04_04_Base']),
#  ('commodity_militaryvehicles,', '2.5', ['RH06_05_Base']),
#  ('commodity_argentium_silver,',
#   '1.0',
#   ['Bw03_01_base', 'Bw03_03_base', 'RH07_02_Base']),
#  ('commodity_cardamine,', '1.098', ['Hi01_01_base']),
#  ('commodity_gapolice,', '1.0', ['IW09_03_Base']),
#  ('commodity_petrochemicals,', '1.145', ['GA01_04_Base']),
#  ('commodity_blood_diamonds,', '10.924', ['Iw01_01_base']),
#  ('commodity_ambassadors,', '1.0', ['Rh01_01_base']),
#  ('commodity_tellurium,', '1.99', ['GA08_03_Base']),
#  ('commodity_violation11,', '1.0', ['IW09_03_Base']),
#  ('commodity_gaadmiral,', '1.0', ['IW09_03_Base']),
#  ('commodity_gadolinium,', '1.99', ['GA05_10_Base']),
#  ('commodity_furs,', '1.0', ['KU08_02_Base']),
#  ('commodity_drillbits,',
#   '1.99',
#   ['Rh03_03_base', 'BR16_02_Base', 'LI09_08_Base', 'EW13_06_Base']),
#  ('commodity_basic_alloys,', '1.195', ['LI09_01_Base']),
#  ('commodity_bm_munitions,', '0.916', ['LI08_01_Base']),
#  ('commodity_bioneural_arrays,',
#   '1.0',
#   ['LI08_01_Base', 'LI08_04_Base', 'GA02_04_Base', 'GA02_05_Base']),
#  ('commodity_slaves,', '1.058', ['Li01_02_base', 'GA06_05_Base']),
#  ('commodity_yttrium,', '1.99', ['GA02_02_Base']),
#  ('commodity_emissaries,', '1.0', ['GA01_14_Base']),
#  ('commodity_filters,', '1.0', ['Iw02_04_Base', 'GA01_05_Base']),
#  ('commodity_pilgrims,', '1.0', ['ST04_02_base']),
#  ('commodity_order,', '1.0', ['IW09_03_Base']),
#  ('commodity_uncut_diamonds,', '1.0', ['IW09_03_Base']),
#  ('commodity_mgeneral,', '1.0', ['IW09_03_Base']),
#  ('commodity_floragro,', '1.396', ['Li02_02_base', 'Li02_07_Base']),
#  ('commodity_food,', '1.5', ['Li02_01_base']),
#  ('commodity_high_performance_alloys,',
#   '1.0',
#   ['Br01_07_base',
#    'Br04_04_base',
#    'BR07_05_Base',
#    'BR07_10_Base',
#    'BR07_11_Base',
#    'EW15_02_Base',
#    'EW15_06_Base',
#    'EW15_07_Base']),
#  ('commodity_leather,', '4.99', ['IW08_03_Base']),
#  ('commodity_tobacco,', '1.69', ['GA01_01_Base']),
#  ('commodity_gacaptain,', '1.0', ['IW09_03_Base']),
#  ('commodity_kucommander,', '1.0', ['IW09_03_Base']),
#  ('commodity_envoys,', '1.0', ['Ku01_01_base', 'Ku01_04_base']),
#  ('commodity_passengers_ku,', '1.0', ['KU08_03_Base', 'EW15_01_Base']),
#  ('commodity_neon,', '1.29', ['LI09_07_Base']),
#  ('commodity_elixirs,', '1.0', ['Br04_07_base']),
#  ('commodity_hydrogro,', '1.356', ['Bw09_02_base']),
#  ('commodity_lasers,', '1.395', ['GA04_10_Base']),
#  ('commodity_firepearls,', '5.0', ['Ku02_04_base']),
#  ('commodity_marijuana,', '1.0', ['EW16_06_Base']),
#  ('commodity_textberne,', '1.0', ['IW09_03_Base']),
#  ('commodity_pearls,', '1.0', ['Ku02_04_base']),
#  ('commodity_brcaptain,', '1.0', ['IW09_03_Base']),
#  ('commodity_mining_machinery,',
#   '1.99',
#   ['Br01_06_base',
#    'Ku01_02_base',
#    'Rh01_06_base',
#    'Rh01_06_base',
#    'Rh01_08_base',
#    'LI09_08_Base']),
#  ('commodity_engine_components,', '1.0', ['Ku04_03_base']),
#  ('commodity_beryllium_ca,', '1.89', ['Br03_06_base']),
#  ('commodity_violation1,', '1.0', ['IW09_03_Base']),
#  ('commodity_ga_artifacts,', '1.0', ['Bw05_03_base', 'Bw07_01_base']),
#  ('commodity_sightseers,', '1.0', ['Li02_01_base']),
#  ('commodity_credit5,', '1.0', ['Iw05_01_base']),
#  ('commodity_passengers_rh,', '1.0', ['Rh03_02_base']),
#  ('commodity_violation10,', '1.0', ['IW09_03_Base']),
#  ('commodity_munitions,', '1.0', ['GA03_01_Base', 'GA03_08_Base']),
#  ('commodity_catalysts,', '1.99', ['GA01_08_Base']),
#  ('commodity_brcommander,', '1.0', ['IW09_03_Base']),
#  ('commodity_passengers_li,', '1.0', ['IW12_01_Base', 'GA07_03_Base']),
#  ('commodity_mox_fuel,', '13.304', ['Bw01_06_Base']),
#  ('commodity_vacationers,', '0.619', ['KU08_02_Base']),
#  ('commodity_robocultivars,', '1.0', ['Ku04_01_base']),
#  ('commodity_rum,', '1.99', ['BW13_02_Base']),
#  ('commodity_prisoners_li,', '4.03', ['Li04_05_base']),
#  ('commodity_violation2,', '1.0', ['IW09_03_Base']),
#  ('commodity_vanadium,', '1.89', ['IW07_01_Base']),
#  ('commodity_niobium,', '1.036', ['Ew01_02_base']),
#  ('commodity_ganavy,', '1.0', ['IW09_03_Base']),
#  ('commodity_diamonds,', '13.324', ['Li01_01_base']),
#  ('commodity_arbiters,', '1.0', ['BW69_02_Base']),
#  ('commodity_sidearms,', '10.62', ['Rh05_01_base']),
#  ('commodity_cardamine_rt,', '1.998', ['Li01_12_base']),
#  ('commodity_corehardware,', '1.0', ['BW71_03_Base', 'LI10_01_Base']),
#  ('commodity_gold,', '1.596', ['Br05_03_base']),
#  ('commodity_criminals_bhg,', '1.0', ['Br02_03_base']),
#  ('commodity_history,',
#   '1.0',
#   ['Br01_01_base',
#    'Hi01_01_base',
#    'Hi02_01_base',
#    'Ku01_01_base',
#    'Li01_01_base',
#    'Rh01_01_base',
#    'ST05_01_Base',
#    'IW09_01_Base',
#    'IW09_02_Base',
#    'IW09_03_Base']),
#  ('commodity_solarpanels,', '1.145', ['GA06_04_Base']),
#  ('commodity_tourists,', '1.0', ['Li02_02_base', 'EW14_04_Base']),
#  ('commodity_lightarms,', '10.08', ['LI13_03_Base']),
#  ('commodity_oil,', '135.75', ['Br04_04_base']),
#  ('commodity_passengers_br,', '1.0', ['Br04_07_base', 'GA08_06_Base']),
#  ('commodity_crew,',
#   '1.0',
#   ['Br01_02_base',
#    'Br02_01_base',
#    'Bw05_02_base',
#    'Bw09_03_base',
#    'Ew01_01_base',
#    'Ew03_02_base',
#    'Ew04_02_base',
#    'Hi02_02_base',
#    'Ku01_03_base',
#    'Ku02_01_base',
#    'Ku04_03_base',
#    'ew37_01_base',
#    'Li01_07_base',
#    'Li01_14_base',
#    'Rh01_02_base',
#    'Rh02_03_base',
#    'Rh02_04_base',
#    'Ew06_03_base',
#    'ST04_02_base',
#    'BR22_03_Base',
#    'BW16_02_Base',
#    'BW71_03_Base',
#    'BW69_01_Base',
#    'EW85_04_Base',
#    'HI10_01_Base',
#    'IW08_02_Base',
#    'KU17_01_Base',
#    'KU17_02_Base',
#    'LI15_04_Base',
#    'LI18_04_Base',
#    'KU16_03_Base',
#    'Hi01_03_base',
#    'Li05_03_Base',
#    'HI20_03_Base',
#    'LI13_04_Base',
#    'IW13_03_Base',
#    'BW46_03_Base',
#    'LI16_03_Base',
#    'Bw01_06_Base',
#    'HI03_04_Base',
#    'IW11_03_Base',
#    'LI07_01_Base',
#    'LI10_03_Base',
#    'EW18_01_Base',
#    'GA01_13_Base',
#    'GA01_19_Base',
#    'GA02_03_Base',
#    'GA05_03_Base',
#    'GA05_05_Base',
#    'GA06_08_Base']),
#  ('commodity_high_temp_alloys,', '1.495', ['RH06_05_Base']),
#  ('commodity_rheinbier,', '1.99', ['Rh01_01_base']),
#  ('commodity_wild,', '1.0', ['IW09_03_Base']),
#  ('commodity_nucleardevices,', '1.0', ['Rh04_03_base']),
#  ('commodity_pineal_amulets,', '2.01', ['IW12_01_Base', 'IW12_02_Base']),
#  ('commodity_marines,',
#   '1.0',
#   ['Ku01_01_base', 'Li01_09_base', 'Rh01_01_base']),
#  ('commodity_samarium,', '1.99', ['EW15_01_Base']),
#  ('commodity_tea,', '1.0', ['Iw04_01_base']),
#  ('commodity_oxygen,',
#   '1.0',
#   ['Br01_01_base',
#    'Br03_01_base',
#    'Br04_01_base',
#    'Bw01_01_base',
#    'Bw06_01_base',
#    'Bw10_01_base',
#    'Hi01_01_base',
#    'Hi02_01_base',
#    'Iw04_01_base',
#    'Ku01_01_base',
#    'Ku02_04_base',
#    'Ku03_01_base',
#    'Ku04_01_base',
#    'Li01_01_base',
#    'Li01_02_base',
#    'Li02_01_base',
#    'Li03_01_base',
#    'Rh01_01_base',
#    'Rh02_01_base',
#    'Rh03_01_base',
#    'Rh03_02_base',
#    'Rh04_01_base',
#    'Ew06_02_base',
#    'EW08_01_Base',
#    'RH06_05_Base',
#    'BW16_03_Base',
#    'BW16_04_Base',
#    'HI18_02_Base',
#    'IW07_01_Base',
#    'RH11_03_Base',
#    'LI09_07_Base',
#    'KU08_02_Base',
#    'KU13_06_Base',
#    'IW11_04_Base',
#    'IW11_05_Base',
#    'IW09_03_Base',
#    'BW14_02_Base',
#    'BW15_01_Base',
#    'ST08_03_Base',
#    'EW13_01_Base',
#    'EW15_01_Base',
#    'EW16_01_Base',
#    'EW16_08_Base',
#    'GA01_01_Base',
#    'GA01_02_Base',
#    'GA01_03_Base',
#    'GA02_01_Base',
#    'GA02_02_Base',
#    'GA03_01_Base',
#    'GA04_01_Base',
#    'GA05_02_Base',
#    'GA05_10_Base',
#    'GA06_05_Base',
#    'GA06_06_Base',
#    'GA08_01_Base',
#    'GA09_01_Base']),
#  ('commodity_consumer_goods_ku,', '11.22', ['Ku05_02_base']),
#  ('commodity_diplomats,', '1.0', ['Br01_01_base', 'Br01_04_base']),
#  ('commodity_medstasis,', '1.245', ['Br03_02_base']),
#  ('commodity_palladium,', '1.245', ['ST08_03_Base']),
#  ('commodity_gaianlife,', '1.0', ['Bw10_01_base']),
#  ('commodity_magnetic_superconductors,',
#   '1.0',
#   ['Li03_04_base', 'LI07_01_Base', 'GA04_08_Base', 'GA04_09_Base']),
#  ('commodity_construction_machinery,', '2.29', ['Bw01_06_Base']),
#  ('commodity_vips,', '1.0', ['Iw04_01_base', 'GA06_01_Base', 'GA08_04_Base']),
#  ('commodity_pirates,', '1.0', ['IW09_03_Base']),
#  ('commodity_critical_temp_alloys,',
#   '1.0',
#   ['Rh04_02_base',
#    'RH06_01_Base',
#    'RH06_05_Base',
#    'RH06_06_Base',
#    'RH06_07_Base',
#    'EW15_02_Base',
#    'EW15_06_Base',
#    'EW15_07_Base']),
#  ('commodity_super_alloys,', '2.99', ['BR07_05_Base']),
#  ('commodity_nox,', '1.0', ['GA08_01_Base']),
#  ('commodity_elitepilot,', '1.0', ['IW09_03_Base']),
#  ('commodity_kuwild,', '1.0', ['IW09_03_Base']),
#  ('commodity_freelancer,', '1.0', ['IW09_03_Base']),
#  ('commodity_synthpaste,', '107.3', ['Rh04_01_base']),
#  ('commodity_holo_bands,', '11.416', ['GA04_04_Base']),
#  ('commodity_gate_lane_parts,', '5.0', ['GA03_11_Base']),
#  ('commodity_armaments,',
#   '1.0',
#   ['Li01_10_base',
#    'Li01_13_base',
#    'Rh01_01_base',
#    'Rh01_03_base',
#    'Rh01_08_base',
#    'GA03_01_Base',
#    'GA03_02_Base']),
#  ('commodity_credit3,', '1.0', ['IW09_03_Base']),
#  ('commodity_optronic_arrays,',
#   '1.0',
#   ['Ku04_01_base', 'EW37_02_Base', 'BW13_01_Base']),
#  ('commodity_criminals,', '1.0', ['Ku05_03_base', 'BR09_03_Base']),
#  ('commodity_homesteaders,', '1.0', ['Li04_01_base']),
#  ('commodity_consumer_goods_rh,', '10.94', ['Rh03_03_base']),
#  ('commodity_ablativearmor,', '1.0', ['Rh02_04_base']),
#  ('commodity_pioneers,', '1.0', ['GA09_01_Base']),
#  ('commodity_gin,', '1.99', ['Br01_01_base']),
#  ('commodity_pvpserverrules,', '1.0', ['IW09_03_Base']),
#  ('commodity_kucaptain,', '1.0', ['IW09_03_Base']),
#  ('commodity_robotic_hardware,',
#   '1.25',
#   ['Bw01_01_base',
#    'Bw10_02_base',
#    'Ew03_02_base',
#    'Ku04_01_base',
#    'EW37_02_Base',
#    'Li02_01_base',
#    'Li02_06_base',
#    'Ew06_02_base',
#    'LI12_06_Base',
#    'Bw01_06_Base',
#    'HI03_03_Base',
#    'KU13_02_Base',
#    'RH07_01_Base',
#    'RH07_02_Base',
#    'ST07_01_Base',
#    'GA04_09_Base',
#    'GA04_10_Base']),
#  ('commodity_zoners,', '1.0', ['IW09_03_Base']),
#  ('commodity_fine,', '1.0', ['IW09_03_Base']),
#  ('commodity_synthgel,', '0.95', ['Li02_01_base']),
#  ('commodity_luxury_consumer_goods,',
#   '1.596',
#   ['Li02_01_base', 'GA04_08_Base']),
#  ('commodity_phantom,', '1.0', ['IW09_03_Base']),
#  ('commodity_prometheum,', '1.0', ['EW16_08_Base']),
#  ('commodity_titanium,', '1.79', ['Bw01_01_base']),
#  ('commodity_toxic_waste,', '1.0', ['BW16_02_Base']),
#  ('commodity_kelite,', '1.0', ['IW09_03_Base']),
#  ('commodity_software,', '12.69', ['Iw03_02_base']),
#  ('commodity_aluminium,', '1.79', ['RH06_08_Base']),
#  ('commodity_industrial,',
#   '1.0',
#   ['Li01_06_base', 'Rh04_02_base', 'BR07_04_Base']),
#  ('commodity_humanorgans,', '1.0', ['GA03_02_Base']),
#  ('commodity_royal_marines,', '1.0', ['GA01_03_Base']),
#  ('commodity_plutonium,',
#   '1.0',
#   ['KU13_01_Base', 'KU13_02_Base', 'KU13_06_Base', 'KU13_10_Base']),
#  ('commodity_pharm,', '2.59', ['Li03_01_base']),
#  ('commodity_mcaptain,', '1.0', ['IW09_03_Base']),
#  ('commodity_holosculptures,', '1.0', ['Bw07_01_base']),
#  ('commodity_quantum_arrays,',
#   '1.0',
#   ['BR16_02_Base', 'KU10_01_Base', 'GA06_04_Base']),
#  ('commodity_rhadmiral,', '1.0', ['IW09_03_Base']),
#  ('commodity_polymers,',
#   '1.0',
#   ['Bw01_03_base', 'Bw01_04_base', 'Ku03_02_base']),
#  ('commodity_gabrigands,', '1.0', ['IW09_03_Base']),
#  ('commodity_socialites,', '1.0', ['Li01_01_base', 'Li01_08_base']),
#  ('commodity_vodka,', '1.495', ['EW09_04_Base']),
#  ('commodity_plasmonics,',
#   '1.0',
#   ['Br05_01_base',
#    'Br05_03_base',
#    'Br05_05_base',
#    'Br06_03_base',
#    'Br06_04_base']),
#  ('commodity_passengers,', '1.0', ['KU09_03_Base']),
#  ('commodity_cigars,', '1.0', ['Rh04_01_base']),
#  ('commodity_cryocubes,', '2.0', ['GA03_01_Base']),
#  ('commodity_fertilizers,', '1.29', ['Rh04_01_base', 'Rh04_05_base']),
#  ('commodity_nanocapacitors,', '1.036', ['Rh02_01_base']),
#  ('commodity_nanotubes,', '1.195', ['GA01_05_Base']),
#  ('commodity_scientists,',
#   '1.0',
#   ['Br03_02_base',
#    'Iw05_01_base',
#    'Ku03_04_base',
#    'Ku04_04_base',
#    'Li02_04_base',
#    'BR07_02_Base',
#    'Rh04_07_Base',
#    'LI15_03_Base',
#    'EW09_02_Base',
#    'RH08_03_Base',
#    'IW13_04_Base',
#    'Li05_05_Base',
#    'HI03_03_Base',
#    'RH07_02_Base',
#    'EW18_01_Base',
#    'GA01_18_Base',
#    'GA02_07_Base',
#    'GA03_11_Base',
#    'GA07_01_Base']),
#  ('commodity_militaryvehicles_li,', '2.5', ['LI12_04_Base']),
#  ('commodity_silver,', '1.79', ['Bw03_01_base']),
#  ('commodity_hull_segments,',
#   '1.0',
#   ['Br04_02_base',
#    'Br05_05_base',
#    'Br06_03_base',
#    'Hi01_02_base',
#    'Hi02_02_base',
#    'Iw03_01_base',
#    'Ku03_01_base',
#    'Ku03_05_base',
#    'Ku05_02_base',
#    'Li04_01_base',
#    'Li04_04_base',
#    'Rh01_08_base',
#    'Rh02_04_base',
#    'ST04_01_base',
#    'BR07_05_Base',
#    'EW08_02_Base',
#    'IW08_01_Base',
#    'ST08_03_Base',
#    'GA02_03_Base',
#    'GA02_04_Base',
#    'GA02_11_Base',
#    'GA04_05_Base']),
#  ('commodity_mox_rh,', '1.876', ['RH07_01_Base', 'RH07_05_Base']),
#  ('commodity_food_br,', '1.3', ['Br03_01_base']),
#  ('commodity_violation7,', '1.0', ['IW09_03_Base']),
#  ('commodity_terraforming_gases,', '1.99', ['Bw01_04_base']),
#  ('commodity_warning,', '1.0', ['IW09_03_Base']),
#  ('commodity_mlieutenant,', '1.0', ['IW09_03_Base']),
#  ('commodity_holidayers,', '1.0', ['Br03_01_base', 'GA02_10_Base']),
#  ('commodity_volgograd_ord,', '1.5', ['EW09_02_Base', 'EW09_04_Base']),
#  ('commodity_tantalum,', '1.99', ['GA06_10_Base']),
#  ('commodity_consumer_goods,', '10.44', ['Li03_03_base']),
#  ('commodity_sake,', '1.99', ['Ku01_01_base']),
#  ('commodity_bluejillies,', '1.59', ['Rh03_01_base']),
#  ('commodity_maquis,', '1.0', ['IW09_03_Base']),
#  ('commodity_gravity_stabilizers,',
#   '1.0',
#   ['Li03_03_base',
#    'Li03_04_base',
#    'LI12_05_Base',
#    'GA03_02_Base',
#    'GA03_08_Base',
#    'GA03_11_Base']),
#  ('commodity_violation4,', '1.0', ['IW09_03_Base']),
#  ('commodity_criminals_li,', '1.0', ['LI12_04_Base']),
#  ('commodity_violation3,', '1.0', ['IW09_03_Base']),
#  ('commodity_settlers,', '1.0', ['Rh02_01_base']),
#  ('commodity_neodymium,', '1.99', ['KU08_02_Base', 'BW14_02_Base']),
#  ('commodity_copper,', '1.69', ['Bw03_02_base']),
#  ('commodity_molybdenum,', '1.99', ['GA03_05_Base']),
#  ('commodity_council,', '1.0', ['IW09_03_Base']),
#  ('commodity_bradmiral,', '1.0', ['IW09_03_Base']),
#  ('commodity_hypno_bands,', '1.996', ['GA02_04_Base']),
#  ('commodity_luxury_food,', '1.596', ['Br03_01_base', 'GA02_01_Base']),
#  ('commodity_reinforced_alloys,',
#   '2.5',
#   ['Br01_01_base',
#    'Br04_01_base',
#    'Br05_05_base',
#    'Br06_03_base',
#    'Bw01_02_base',
#    'Bw09_03_base',
#    'Ew01_01_base',
#    'Ew04_01_base',
#    'Iw01_02_base',
#    'Iw05_01_base',
#    'Ku01_01_base',
#    'Rh01_01_base',
#    'Rh01_08_base',
#    'ST04_02_base',
#    'EW08_01_Base',
#    'BW71_03_Base',
#    'EW85_01_Base',
#    'LI09_01_Base',
#    'LI09_02_Base',
#    'LI09_04_Base',
#    'LI09_06_Base',
#    'BW15_02_Base',
#    'EW15_02_Base',
#    'EW15_06_Base',
#    'EW15_07_Base',
#    'EW16_01_Base',
#    'EW16_08_Base',
#    'GA02_01_Base',
#    'GA03_02_Base',
#    'GA03_08_Base',
#    'GA03_09_Base',
#    'GA04_05_Base',
#    'GA08_07_Base']),
#  ('commodity_jumpgate_parts,', '5.0', ['Li03_04_base']),
#  ('commodity_flourine,', '1.49', ['BR16_03_Base']),
#  ('commodity_courtiers,', '1.0', ['GA01_12_Base']),
#  ('commodity_multiplexors,', '1.0', ['KU10_01_Base']),
#  ('commodity_rhcommander,', '1.0', ['IW09_03_Base']),
#  ('commodity_survey_team,',
#   '1.0',
#   ['Br03_01_base',
#    'Bw06_02_base',
#    'Bw09_03_base',
#    'Ew03_02_base',
#    'Iw05_01_base',
#    'Ku03_04_base',
#    'Ku04_04_base',
#    'Li02_04_base',
#    'ST04_02_base',
#    'BR07_02_Base',
#    'Rh04_07_Base',
#    'BW71_03_Base',
#    'LI15_03_Base',
#    'BW12_03_Base',
#    'EW09_02_Base',
#    'EW63_01_Base',
#    'LI08_03_Base',
#    'RH08_03_Base',
#    'LI16_01_Base',
#    'HI03_03_Base',
#    'Ku07_02_Base',
#    'KU13_05_Base',
#    'IW11_01_Base',
#    'IW13_06_Base',
#    'IW13_07_Base',
#    'RH07_02_Base',
#    'ST08_03_Base',
#    'EW18_01_Base',
#    'GA01_18_Base',
#    'GA03_11_Base',
#    'GA08_07_Base']),
#  ('commodity_bm_munitions_rh,', '1.996', ['Rh01_03_base']),
#  ('commodity_manifolds,', '1.99', ['LI18_02_Base']),
#  ('commodity_beryllium,', '1.69', ['Bw08_03_base']),
#  ('commodity_propaganda,',
#   '1.0',
#   ['Br03_05_Base',
#    'Br05_05_base',
#    'Iw01_01_base',
#    'Iw02_01_base',
#    'Iw05_02_base',
#    'Ku03_05_base',
#    'EW37_02_Base',
#    'Ku06_01_base',
#    'Li03_03_base',
#    'Rh04_05_base',
#    'Rh05_03_base',
#    'Rh05_04_base',
#    'ST04_01_base',
#    'BR07_09_Base',
#    'BR07_10_Base',
#    'BW13_01_Base',
#    'BW71_01_Base',
#    'IW08_01_Base',
#    'LI10_01_Base',
#    'LI15_02_Base',
#    'EW09_01_Base',
#    'EW09_03_Base',
#    'EW09_04_Base',
#    'BR09_01_Base',
#    'LI12_06_Base',
#    'LI12_07_Base',
#    'LI09_06_Base',
#    'RH08_02_Base',
#    'RH06_04_Base',
#    'RH06_07_Base',
#    'Rh01_10_Base',
#    'LI13_05_Base',
#    'IW13_04_Base',
#    'BW13_03_Base',
#    'Ku07_01_Base',
#    'BR17_01_Base',
#    'BW15_06_Base',
#    'RH07_05_Base',
#    'ST08_03_Base',
#    'EW13_05_Base',
#    'EW15_06_Base',
#    'EW16_03_Base',
#    'EW16_08_Base',
#    'EW17_02_Base',
#    'GA01_15_Base',
#    'GA03_08_Base',
#    'GA07_04_Base',
#    'GA07_05_Base',
#    'GA13_01_Base']),
#  ('commodity_prisoners_ga,',
#   '1.0',
#   ['Br04_01_base', 'EW07_03_Base', 'BR08_05_Base']),
#  ('commodity_industrial_hardware,',
#   '1.0',
#   ['Ku01_02_base',
#    'Ku01_07_base',
#    'Ku05_02_base',
#    'Li01_06_base',
#    'Li01_13_base',
#    'Rh04_02_base',
#    'Rh04_05_base',
#    'BR07_03_Base',
#    'BR07_08_Base',
#    'BR07_11_Base',
#    'RH06_01_Base',
#    'GA02_01_Base',
#    'GA02_04_Base']),
#  ('commodity_alien_organisms,', '1.99', ['Bw06_01_base', 'GA09_01_Base']),
#  ('commodity_belite,', '1.0', ['IW09_03_Base']),
#  ('commodity_bioprocessors,', '1.036', ['LI08_03_Base', 'LI08_04_Base']),
#  ('commodity_tungsten,', '1.195', ['Bw10_01_base']),
#  ('commodity_medical_unit,',
#   '1.0',
#   ['Br03_02_base',
#    'Bw06_02_base',
#    'Bw09_03_base',
#    'Ew03_02_base',
#    'Iw05_01_base',
#    'Ku03_04_base',
#    'Ku04_04_base',
#    'Li02_04_base',
#    'ST04_02_base',
#    'BR07_02_Base',
#    'Rh04_07_Base',
#    'BW71_03_Base',
#    'LI15_03_Base',
#    'BW12_03_Base',
#    'EW09_02_Base',
#    'EW63_01_Base',
#    'LI08_03_Base',
#    'RH08_03_Base',
#    'LI16_01_Base',
#    'HI03_03_Base',
#    'Ku07_02_Base',
#    'KU13_05_Base',
#    'IW11_01_Base',
#    'IW13_06_Base',
#    'IW13_07_Base',
#    'RH07_02_Base',
#    'ST08_03_Base',
#    'EW18_01_Base',
#    'GA01_18_Base',
#    'GA03_11_Base',
#    'GA08_07_Base']),
#  ('commodity_consumer_goods_ga,', '11.38', ['EW14_04_Base']),
#  ('commodity_gcelitepilot,', '1.0', ['IW09_03_Base']),
#  ('commodity_passengers_ga,', '1.0', ['EW15_01_Base']),
#  ('commodity_water,',
#   '1.0',
#   ['Br01_01_base',
#    'Br03_01_base',
#    'Br04_01_base',
#    'Bw01_01_base',
#    'Bw06_01_base',
#    'Bw10_01_base',
#    'Hi01_01_base',
#    'Hi02_01_base',
#    'Iw04_01_base',
#    'Ku01_01_base',
#    'Ku02_04_base',
#    'Ku03_01_base',
#    'Ku04_01_base',
#    'Li01_01_base',
#    'Li02_01_base',
#    'Li03_01_base',
#    'Rh01_01_base',
#    'Rh02_01_base',
#    'Rh03_01_base',
#    'Rh03_02_base',
#    'Rh04_01_base',
#    'Ew06_02_base',
#    'EW08_01_Base',
#    'RH06_05_Base',
#    'BW16_03_Base',
#    'HI18_02_Base',
#    'IW07_01_Base',
#    'RH11_03_Base',
#    'LI09_07_Base',
#    'KU08_02_Base',
#    'KU13_06_Base',
#    'IW11_04_Base',
#    'IW11_05_Base',
#    'BW14_02_Base',
#    'BW15_01_Base',
#    'ST08_03_Base',
#    'EW13_01_Base',
#    'EW15_01_Base',
#    'EW16_01_Base',
#    'EW16_08_Base',
#    'GA01_01_Base',
#    'GA01_02_Base',
#    'GA01_03_Base',
#    'GA02_01_Base',
#    'GA02_02_Base',
#    'GA03_01_Base',
#    'GA04_01_Base',
#    'GA06_06_Base',
#    'GA08_01_Base',
#    'GA09_01_Base']),
#  ('commodity_diodes,',
#   '1.0',
#   ['Rh01_08_base', 'Rh04_03_base', 'RH06_05_Base']),
#  ('commodity_alien_artifacts,', '1.078', ['Hi02_01_base']),
#  ('commodity_biostability,', '1.245', ['GA07_03_Base']),
#  ('commodity_contactadmin,', '1.0', ['IW09_03_Base']),
#  ('commodity_liberty_ale,', '1.99', ['Li01_01_base']),
#  ('commodity_colonists,', '1.0', ['Ku02_03_base']),
#  ('commodity_gallic_fuel,', '1.0', ['EW14_03_Base']),
#  ('commodity_heatsinks,',
#   '1.0',
#   ['Br01_01_base',
#    'Br05_05_base',
#    'Br06_03_base',
#    'GA03_01_Base',
#    'GA03_02_Base',
#    'GA03_08_Base']),
#  ('commodity_nickel,', '1.99', ['GA02_01_Base']),
#  ('commodity_credit4,', '1.0', ['IW09_03_Base'])]

# %%
popout
# Out:
# array([['Br01_01_base', 'commodity_oxygen,', '1.0'],
#        ['Br01_02_base', 'commodity_oxygen,', '3.0'],
#        ['Br01_04_base', 'commodity_oxygen,', '2.0'],
#        ...,
#        ['GA08_08_Base', 'commodity_oxygen,', '5.0'],
#        ['GA09_01_Base', 'commodity_oxygen,', '1.0'],
#        ['GA13_01_Base', 'commodity_oxygen,', '5.0']], dtype='<U35')

# %%
popout
# Out:
# array([['Br01_01_base', 'commodity_oxygen,', '1.0'],
#        ['Br01_02_base', 'commodity_oxygen,', '3.0'],
#        ['Br01_04_base', 'commodity_oxygen,', '2.0'],
#        ...,
#        ['GA08_08_Base', 'commodity_oxygen,', '5.0'],
#        ['GA09_01_Base', 'commodity_oxygen,', '1.0'],
#        ['GA13_01_Base', 'commodity_oxygen,', '5.0']], dtype='<U35')

# %%
class Config(object):
    bases = [] # or load from template

    def __str__(self):
        num_bases = len(self.bases)
        num_commodites = sum([len(comm) for comm in self.bases]) #counts the number of objects inside the bases
        return "this config has {} bases with {} commodies filled".format(str(num_bases), str(num_commodites))

# %%
c = Config()

# %%
c.bases
pnl = ['metal', 'rocks','gold','FOW','munitions']

# %%
c.bases.append(pnl)

# %%
print(c)
# Out:
# this config has 1 bases with 5 commodies filled

# %% [markdown]
# small economy: Find the 30 bases closest to X

# %%
corfu8 = find_nearest_x('Corfu Base', 7, distances)
corfu8.append(base_code_lookup['Corfu Base'].lower())

# %%
c30_coms = ['Food', 
            'water', 
            'fuel', 
            'air', 
            'o2', 
            'guns',
            'metal',
            'rocks',
            'batteries',
            'cattle',
            'electrics',
            'scrap',
            'toxins',
            'plastics',
            'toys',
            ]
c8_coms = ['toxins', 'toys', 'metal','scrap','electrics', 'rocks','air','water','batteries','guns','fuel','o2','cattle']

# %%
dist =distances[distances['end'].isin(corfu8)]
distc8 = dist[dist['start'].isin(corfu8)]

# %% [markdown]
# config =[[base,[produced commodity], [resold commodity], [bought commodity]]]

# %%
[base_name_lookup[code] for code in corfu8]
# Out:
# ['Corfu Base']

# %%
config = [['ew12_04_base', ['toxins', 'toys'],[],['cattle','o2','metal','scrap','electrics','air']],
        ['ew04_01_base',['scrap', 'electrics', 'rocks'], [],['cattle','air', 'water', 'metal', 'batteries','air']],
        ['ga09_01_base',['guns', 'air'],['toxins'],['cattle','o2','water','fuel','metal', 'batteries','electrics']],
        ['bw06_01_base',['cattle','batteries', 'o2'],['air'],['metal','toxins','air']],
        ['ga01_16_base',['fuel','metal'],['air'],['cattle','toxins','electrics','rocks','o2']],
        ['ga14_01_base',['water','electrics','o2'],['air'],['cattle','rocks', 'batteries', 'toxins']],
        ['ew06_02_base',['cattle', 'rocks','scrap'],[],['toxins','o2','water','air', 'toys', 'electrics','air','metal']],
        ['bw12_02_base',['fuel','air','metal'],[],['water', 'o2','cattle']],
        ['ew07_02_base',['water','guns'],['o2'],['fuel','electrics', 'rocks','air','metal']],
        #['hi18_04_base',['metal','scrap'],[],['fuel','rocks', 'Food']],
        #['bw06_02_base',['rocks'],[],['air', 'water']],
        #['ku08_01_base',['electrics'],[],['water','guns','batteries']],
        #['hi02_01_base',['scrap'],[],['toys','water','metal']],
        #['bw12_05_base',['toxins'],['toys'],['plastics','batteries']],
        #['hi18_03_base',['plastics'],[],['toxins','fuel','air','water']],
        #['ga08_09_base',['water','Food'],[],['rocks']],
        #['ga03_10_base',['fuel'],[],['cattle','scrap','guns']],
        #['ga05_11_base',['air'],[],['guns','plastics']],
        #['ew06_05_base',['toys'],[],['batteries','rocks','scrap']],
        #['hi02_02_base',['cattle'],[],['scrap','guns','fuel','water']],
        #['ew06_01_base',['toys'],[],['batteries','cattle','scrap', 'Food']],
        #['bw05_03_base',['o2'],[],['toys','guns','fuel', 'Food']],
        #['bw69_03_base',['guns', 'Food'],[],['toxins','metal','plastics','cattle']],
        #['hi02_03_base',['o2'],[],['air','plastics']],
        #['bw07_01_base',['air'],[],['toys', 'water', 'Food']],
        #['ew06_03_base',['guns'],[],['scrap','metal','rocks']],
        #['bw01_05_base',['metal'],[],['scrap','electrics','cattle']],
        #['hi20_02_base',['rocks'],[],['metal','batteries','toys']],
        #['rh10_02_base',['cattle'],['scrap'],['batteries','fuel','o2']],
        ['ew04_02_base',['batteries'],[],['water','toxins','guns', 'scrap', 'metal','electrics','air']]]

# %%
market =gen_market_from_config(config, distances)

# %% [markdown]
# ++++++++++======================================================================+++++++++++

# %%
market['ga01_16_base']
# Out:
# ('metal', 'sells', 1)

# %%
file_path ='test_market.ini'
def write_ini(file_path, market, config):
    '''
    function that takes the market dictonary and formats it for freelancer, and saves it as a text file
    ++++++++++
    Parameters
    file_path (str): name and path of file
    market (defaultdict(list)): per base formatting of all commodities
    ++++++++++
    Returns:
    none, 
    writes a file
    '''
    lines = []
    for item in market.keys():

        lines.append('[BaseGood]')
        lines.append('base = '+ item)
        lines.append(';'+base_name_lookup[item])

        for commodity in market[item]:
            if commodity[1] == 'sells':
                function_tag = '1'
            else:
                function_tag = '0'
            price_mult = str(commodity[2]) # For a working version, this needs to reference something in config to set prices
            mgood =['Marketgood =',commodity[0],'0, -1, 0, 0,', function_tag, str(commodity[2])]
            lines.append(' '.join(mgood))

    with open(file_path, 'w') as f:
        for line in lines:
            f.write(line+'\n')

# %% [markdown]
# per base that is buying
# Marketgood = commodity_ablativearmor, 0, -1, 0, 0, 1, 5.778000

# %%
write_ini(file_path,market, config)

# %%
with open('base_code_lookup.csv', 'w') as f:
    for key in base_code_lookup.keys():
        f.write("%s, %s\n" % (key, base_code_lookup[key]))

# %%
sortd, df =sort_by_closest_base(['st39_04_base', 'br01_04_base'], distances)

# %%
len(sortd[0])

# %%
sortd.
#for i in list_of_bases:

# %%
df

# %%
bases
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b238e71c0c3e> in <module>
# ----> 1 bases
#
# NameError: name 'bases' is not defined
